# %% [markdown]
# # Image Superresolution

# %% [markdown]
# ## Key takeaways from paper

# %% [markdown]
# ![title](srarch.png)
# ![title](loss.png)

# %% [markdown]
# ## Implementation

# %%
# %matplotlib inline
